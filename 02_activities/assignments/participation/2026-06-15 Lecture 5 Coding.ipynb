# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
sns.set_style('dark') # can customize the style yourself using the set style function
sns.lineplot(data=tips,x='total_bill',y='tip')

#add title and axis labels
tipgraph = sns.lineplot(data=tips,
                        x='total_bill',
                        y='tip')
tipgraph.set(title='Tips vs Total.Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# [Text(0.5, 1.0, 'Tips vs Total.Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tips = sns.load_dataset("tips")
print(tips)
sns.set_style('dark') 
sns.lineplot(data=tips,x='total_bill',y='tip',
             color='hotpink', #can change other aestetic features on your graph with seaborn as well
             linestyle='--',
             linewidth=3,
             marker='o',
             markerfacecolor='indigo')

#add title and axis labels
tipgraph = sns.lineplot(data=tips,
                        x='total_bill',
                        y='tip')
tipgraph.set(title='Tips vs Total.Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# [Text(0.5, 1.0, 'Tips vs Total.Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.scatterplot(data=tips, 
                           x='total_bill',
                           y='tip', 
                           style='time',
                           hue='day', 
                           palette=['purple', 'hotpink', 'deepskyblue','yellowgreen'])

tipgraph.set(title='Tips vs Total Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
daysplot = sns.relplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="sex", #changes the colour of the points based on sex (e.g., Male vs Female)
    col="day",
    kind="scatter",
    col_wrap=2) # means to wrap data into 2 columns per row

# %%
#set up packages needed to create interactive/dynamic plots
import plotly.graph_objects as go
from wordcloud import WordCloud
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

# %%
#define x and y axes
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
#make our plot
graph = go.Figure()

#chose plot type (bar) and select the data
graph.add_trace(go.Bar(x=x1,y=y1))

# %%
#update plot layout to include titles
graph.update_layout(
    title="Pirate Scores",
    xaxis_title="Pirates",
    yaxis_title="Score")

graph.write_html("pirategraph.html")

# %%
#do some more design customizations (e.g., marker size and colour, plot size)
graph=go.Figure()
graph.add_trace(go.Scatter(x=x1,y=y1,mode="markers", marker=dict(size=15,color='hotpink',opacity=1,line=dict(width=5,color='purple'))))
graph.update_layout(title='Interactive Pirate Plot',
                    xaxis_title='Pirates',
                    yaxis_title='Scores',
                    width=500, height=500)

# %%
#import movie quotes data
df = pd.read_csv("movie_quotes.csv")
print(df)
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# ...

# %%
text="".join(each for each in df.quote)
wordcloud=WordCloud(background_color="white",colormap="inferno").generate(text)

fig,ax=plt.subplots(figsize=(7,3))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
#making a venn diagram
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram=venn2_unweighted([A, B],
                         set_labels = ('Fruits','Pies'),
                         set_colors=("blue","red"),
                         alpha=0.5)

#code to label each region of the venn diagram (note that the numbers in the brackets come from the documentation)
diagram.get_label_by_id("10").set_text("\n".join(A - B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B - A))

plt.show()
# Out:
# c:\Users\ziral\Documents\MSc_PhD Nutritional Science\Data Science Institute Certificate\Assignments\visualization\visualization-env\Lib\site-packages\matplotlib_venn\_util.py:32: UserWarning:
#
# venn2_unweighted is deprecated. Use venn2 with the appropriate layout_algorithm instead.
